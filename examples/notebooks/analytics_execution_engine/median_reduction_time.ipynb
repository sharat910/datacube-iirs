# %%
# median reduction over time

# %matplotlib inline
import mpld3; mpld3.enable_notebook()

from datetime import datetime
from datacube.analytics.analytics_engine import AnalyticsEngine
from datacube.execution.execution_engine import ExecutionEngine
from datacube.analytics.utils.analytics_utils import plot

# %%
# initialise AE/EE

a = AnalyticsEngine()
e = ExecutionEngine()

# %%
# Lake Burley Griffin
dimensions = {'x':    {'range': (79, 79.18)},
              'y':    {'range': (30.32, 30.28)},
              'time': {'range': (datetime(1995, 1, 1), datetime(1995, 12, 31))}}

arrays = a.create_array(('LANDSAT_5', 'ledaps'), ['nir'], dimensions, 'get_data')

median = a.apply_expression(arrays, 'var(array1, 0)', 'medianT')
# Out:
# [u'ls5_ledaps_albers']

# %%
e.execute_plan(a.plan)

# %%
plot(e.cache['get_data'])
# Out:
# plot3D

# %%
plot(e.cache['medianT'])
# Out:
# plot2D
